# %%
import requests

# %%
# import urllib # OLD

# %%
res = requests.get('https://comic.naver.com/index.nhn')
## #genreRecommand > li:nth-child(1) > .genreRecomImg2 img

# %%
res.status_code
# Out:
# 200

# %%
res.text # 한글이 깨지면 -> res.encoding = 'utf-8' or 'cp949' or None
# Out:
# '\r\n\r\n\r\n  \r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="ko">\r\n<head>\r\n\t\r\n\t\t\r\n\t\t\r\n\t\t\r\n\t\t\r\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\r\n\t\t\r\n\t<meta http-equiv="Content-type" content="text/html; charset=UTF-8">\r\n\t<title>네이버 만화</title>\r\n\t\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n        <meta property="og:title" content="네이버 웹툰" >\r\n        <meta property="og:image" content="https://ssl.pstatic.net/static/comic/images/og_tag_v2.png" >\r\n        <meta property="og:description" content="매일매일 새로운 재미, 네이버 웹툰.">\r\n    \r\n\r\n\r\n<meta property="og:url" content="https://comic.naver.com/index.nhn" >\r\n<meta property="og:type" content="article" >\r\n<meta property="og:article:author" content="네이버 웹툰" >\r\n<meta property="og:article:author:url" content="https://comic.naver.com" >\r\n\r\n\t<link rel="shortcut icon" href="https://ssl.pstatic.net/static/comic/favicon/webtoon_favicon_32x32.ico" type="image/x-icon">\r\n\t\r\n\t<script type="text/javascript">\r\n\t\tdocument.domain = "naver.com";\r\n\t</script>\r\n\t<script type="text/javascript">function windowOpen(url){location.href = url;}function goArtistTitle(element, area, titleId, index, event) {nclk_v2(event,area,\'\',index);return artistAction.viewArtist(titleId, element);}</script>\n\t<script type="text/javascript">\n        var g_ssc = "comic.home";\n        var ccsrv = "cc.naver.com";\n\t</script>\n\t\n\t\t\t\n\t\t\t<script type="text/javascript" src="/aggregate/javascript/release/comic_main_20210617144543.js"></script>\n\t\t\n\t\t\n\t\n\t\t\n\t\t<link rel="stylesheet" style="text/css" href="/css/comic/comic_20210617144543.css">\r\n\t\r\n\t\t<script type="text/javascript" src="/aggregate/javascript/release/comic_gnb_20210617144543.js"></script>\r\n\t\r\n</head>\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<body onload="">\r\n\r\n\t\r\n\t\r\n\t\t\r\n\t\t\r\n\t\r\n\t<div id="wrap"  class="end_page"    >\r\n\t\t\r\n\r\n\t\t\r\n\t\t\t\r\n\t\t\t\r\n\t\t\t\t<div id="u_skip">\r\n\t\t\t\t\t<a href="#menu" onclick="document.getElementById(\'menu\').tabIndex=-1;document.getElementById(\'menu\').focus();return false;"><span>메인 메뉴로 바로가기</span></a>\r\n\t\t\t\t\t<a href="#content" onclick="document.getElementById(\'content\').tabIndex=-1;document.getElementById(\'content\').focus();return false;"><span>본문으로 바로가기</span></a>\r\n\t\t\t\t</div>\r\n\t\t\t\r\n\t\t\r\n\t\t<div id="header_wrap">\r\n\t\t\t<div id="header">\r\n\t\t\t\t\r\n\r\n\r\n\r\n<div id="gnb">\r\n    <script type="text/javascript">\r\n        var gnb_option = {\r\n            gnb_service : "comic",\r\n            gnb_logout :  encodeURIComponent(window.location.href),\r\n            gnb_login :   encodeURIComponent(window.location.href),\r\n            gnb_template : "gnb_utf8",\r\n            gnb_brightness : 1,\r\n            gnb_item_hide_option: 0\r\n        };\r\n    </script>\r\n    <script type="text/javascript" charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?20210617144543"></script>\r\n</div>\r\n\r\n\r\n<div id="snb_wrap">\r\n    <h1>\r\n        <a onclick="nclk_v2(event,\'STA.naverlogo\')" href="https://www.naver.com" title="NAVER" class="Ntxt_naver ">NAVER</a>\r\n        <a onclick="nclk_v2(event,\'STA.comic\')" href="/index.nhn" title="만화" class="Ntxt_comic">만화</a>\r\n        <em class="bar">|</em>\r\n        <a onclick="nclk_v2(event,\'STA.novel\')" href="https://novel.naver.com" title="웹소설" class="Ntxt_novel">웹소설</a>\r\n    </h1>\r\n\r\n    \r\n    <form id="searchForm" name="search" method="get" action="/search.nhn">\r\n        <fieldset>\r\n            <legend>검색</legend>\r\n            <div class="snb_search_box">\r\n                <div class="snb_search_box_sub">\r\n                    \r\n                    \r\n                        \r\n                        \r\n                   ...

# %%
from bs4 import BeautifulSoup as bs

# %%
soup = bs(res.text, 'html.parser')

# %%
img = soup.select_one('#genreRecommand > li:nth-child(1) > .genreRecomImg2 img')

# %%
img
# Out:
# <img alt="모죠의 일지" height="120" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/728015/thumbnail/thumbnail_IMAG04_417f59a7-469f-4a4f-a4da-65818377f134.jpg" title="모죠의 일지" width="218"/>

# %%
filename = img.attrs['src']

# %%
import urllib.request
urllib.request.urlretrieve(filename,'test.jpg')
# Out:
# ('test.jpg', <http.client.HTTPMessage at 0x2cee98ff790>)

# %%
urllib.request.urlretrieve(filename,filename.split('/')[-1])
# Out:
# ('thumbnail_IMAG04_417f59a7-469f-4a4f-a4da-65818377f134.jpg',
#  <http.client.HTTPMessage at 0x2cee91310a0>)
